# %% [markdown]
# # Introduction
#
# In part 1 of this assessment, you will complete several requested SQL queries in order to extract data, analyze, and provide insights from a single provided SQL database. You will also visualize the key results of 3 of these queries. There are also several 'Reflection' questions that ask you to write out a text based answer in the provided markdown cell. Following the guided question and answer section, in part 2 you will explore a second dataset on your own using SQL in order to conduct a preliminary analysis. You will be asked to produce a very short slide presentation highlighting the work you did for this second section.
#
# ## Objectives
# You will be able to:
# - Interpret "word problems" and translate them into SQL queries
# - Decide and perform whichever type of JOIN is best for retrieving desired data
# - Use GROUP BY statements to apply aggregate functions like COUNT, MAX, MIN, and SUM
# - Use the HAVING clause to compare different aggregates
# - Write subqueries to decompose complex queries
# - Visualize data using matplotlib, seaborn, or pandas
# - Choose the correct chart type based on the given data

# %% [markdown]
# ## Part 1: Guided SQL Queries
#
# ### Your Task: Querying a Customer Database
#
# ![toy car picture](images/toycars.jpg)

# %% [markdown]
# ### Business Understanding
# Your employer sells wholesale miniature models of products such as classic cars, motorcycles, and planes. They want you to pull several reports on different segments of their past customers, in order to better understand past sales as well as determine which customers will receive promotional material. They are also interested in investigating which products have performed the best, as well as having several smaller asks.
#
# In addition to providing the requested data from the SQL database you have also been asked to create some basic visuals to display some of the more insightful information. It is up to your discretion to choose the correct plot/chart type for the data in question. **Questions that want you to visualize the results will be explicitly marked**.
#
# ### Data Understanding
# You may remember this database from a previous lab. As a refresher, here's the ERD diagram for this database:
#
# ![ERD picture](images/ERD.png)
#
# The queries you are asked to write will become more complex over the course of the lab.

# %% [markdown]
# ### Getting Started
# For this assessment you are expected to make use of both sqlite3 and the Pandas libraries in order to write, execute, and return SQL queries as a Pandas DataFrame. Assign each returned answer as its own explicit variable.
#
# For the visualization piece you are expected to utilize either Pandas, Seaborn, or Matplotlib to create your visuals. Make sure you are providing verbose labels and titles according to the data you are being asked to visualize. Do not worry too much about choosing a 'style' or 'context' instead focus on conveying the requested information correctly.
#
# ### Step 1: Connect to Data
#
# In the cell below
# - Import the necessary libraries
# - Establish a connection to the database data.sqlite

# %%
# Replace None with your code
# Imports
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Create connection to database
conn = sqlite3.connect('data.sqlite')

pd.read_sql("""SELECT * FROM sqlite_master""", conn)
# Out:
#     type          name      tbl_name  rootpage  \
# 0  table  orderdetails  orderdetails         2
# 1  table      payments      payments        28
# 2  table       offices       offices        32
# 3  table     customers     customers        33
# 4  table        orders        orders        38
# 5  table  productlines  productlines        46
# 6  table      products      products        47
# 7  table     employees     employees        56
#
#                                                  sql
# 0  CREATE TABLE `orderdetails` (`orderNumber`, `p...
# 1  CREATE TABLE `payments` (`customerNumber`, `ch...
# 2  CREATE TABLE `offices` (`officeCode`, `city`, ...
# 3  CREATE TABLE `customers` (`customerNumber`, `c...
# 4  CREATE TABLE `orders` (`orderNumber`, `orderDa...
# 5  CREATE TABLE `productlines` (`productLine`, `t...
# 6  CREATE TABLE `products` (`productCode`, `produ...
# 7  CREATE TABLE `employees` (`employeeNumber`, `l...

# %% [markdown]
# ### Step 2: Limited Edition California Product
# The California sales rep team is interested in running promotional material for a new limited edition model they are releasing based on the famous San Francisco Cable Cars. This product will only be available to customer stores based in California and given its high price value they want to first target promotional material to existing California customers with a high credit limit. Upon communicating with the accounting department, a credit limit of over 25,000 is considered to be high.
#
# Execute a SQl query that returns which customers the sales rep team wants to market to first.
# *Hint*: Make sure creditLimit is numeric.

# %%
# Replace None with your code
step2 = pd.read_sql("""
    SELECT *
    FROM customers
    WHERE state = 'CA'
    AND CAST(creditLimit AS REAL) > 25000
""", conn)

step2
# Out:
#   customerNumber                  customerName contactLastName  \
# 0            124  Mini Gifts Distributors Ltd.          Nelson
# 1            129               Mini Wheels Co.          Murphy
# 2            161          Technics Stores Inc.       Hashimoto
# 3            205             Toys4GrownUps.com           Young
# 4            239  Collectable Mini Designs Co.        Thompson
# 5            321      Corporate Gift Ideas Co.           Brown
# 6            347    Men 'R' US Retailers, Ltd.        Chandler
# 7            450     The Sharp Gifts Warehouse           Frick
# 8            475   West Coast Collectables Co.        Thompson
# 9            487      Signal Collectibles Ltd.          Taylor
#
#   contactFirstName       phone               addressLine1 addressLine2  \
# 0            Susan  4155551450            5677 Strong St.
# 1            Julie  6505555787  5557 North Pendale Street
# 2             Juri  6505556809          9408 Furth Circle
# 3            Julie  6265557265         78934 Hillside Dr.
# 4          Valarie  7605558146           361 Furth Circle
# 5            Julie  6505551386            7734 Strong St.
# 6            Brian  2155554369           6047 Douglas Av.
# 7              Sue  4085553659             3086 Ingle Ln.
# 8            Steve  3105553722          3675 Furth Circle
# 9              Sue  4155554312          2793 Furth Circle
#
#             city state postalCode country salesRepEmployeeNumber creditLimit
# 0     San Rafael    CA      97562     USA                   1165   210500.00
# 1  San Francisco    CA      94217     USA                   1165    64600.00
# 2     Burlingame    CA      94217     USA                   1165    84600.00
# 3       Pasadena    CA      90003     USA                   1166    90700.00
# 4      San Diego    CA      91217     USA                   1166   105000.00
# 5  San Francisco    CA      94217     USA                   1165   105000.00
# 6    Los Angeles    CA      91003     USA                   1166    57700.00
# 7       San Jose    CA      94217     USA                   1165    77600.00
# 8        Burbank    CA      94019     USA                   1166    55400.00
# 9       Brisbane    CA      94217     USA                   1165    60300.00

# %% [markdown]
# ### Step 3: International Collectable Campaign
#
# The international sales rep team has reached out to you to help them identify partners for a 'Collectable' marketing campaign that highlights the potential collectors value in purchasing these model kits. They want to try and promote a 'collect them all' mentality. The team had a great idea to partner with any of their international customers (non-US) who have "Collect" in their name as a tie in to the larger theme.
#
# Execute a SQL that returns the customers in question.

# %%
# Replace None with your code
step3 = pd.read_sql("""
    SELECT *
    FROM customers
    WHERE country <> 'USA'
    AND customerName LIKE '%Collect%'
 """, conn)

step3
# Out:
#    customerNumber                        customerName contactLastName  \
# 0             114          Australian Collectors, Co.        Ferguson
# 1             189             Clover Collections, Co.         Cassidy
# 2             201               UK Collectables, Ltd.           Devon
# 3             211         King Kong Collectables, Co.             Gao
# 4             227                Heintze Collectables           Ibsen
# 5             260   Royal Canadian Collectables, Ltd.         Lincoln
# 6             293                   BG&E Collectables        Harrison
# 7             353                  Reims Collectables         Henriot
# 8             376               Precious Collectables             Urs
# 9             382               Salzburg Collectables           Pipps
# 10            398             Tokyo Collectables, Ltd       Shimamura
# 11            409      Stuttgart Collectable Exchange          Müller
# 12            415  Bavarian Collectables Imports, Co.     Donnermeyer
# 13            471        Australian Collectables, Ltd        Clenahan
# 14            480           Kremlin Collectables, Co.         Semenov
#
#    contactFirstName               phone               addressLine1  \
# 0             Peter        03 9520 4555          636 St Kilda Road
# 1              Dean      +353 1862 1555             25 Maiden Lane
# 2         Elizabeth      (171) 555-2282  12, Berkeley Gardens Blvd
# 3              Mike      +852 2251 1555        Bank of China Tower
# 4             Palle          86 21 3555              Smagsloget 45
# 5        Elizabeth       (604) 555-4555         23 Tsawassen Blvd.
# 6                Ed    +41 26 425 50 01       Rte des Arsenaux 41
# 7             Paul           26.47.1555         59 rue de l'Abbaye
# 8             Braun         0452-076555               Hauptstr. 29
# 9            Georg            6562-9555                Geislweg 14
# 10            Akiko     +81 3 3584 0555             2-2-8 Roppongi
# 11            Rita          0711-555361          Adenauerallee 900
# 12          Michael   +49 89 61 08 9555               Hansastr. 15
# 13             Sean      61-9-3844-6555             7 Allen Street
# 14       Alexander      +7 812 293 0521            2 Pobedy Square
#
#      addressLine2               city     state postalCode      country  \
# 0         Level 3          Melbourne  Victoria       3004    Australia
# 1     Floor No. 4             Dublin                    2      Ireland
# 2                          Liverpool              WX1 6LT           UK
# 3   1 Garden Road  Central Hong Kong                         Hong Kong
# 4                              Århus                 8200      Denmark
# 5                          Tsawassen        BC    T2F 8M4       Canada
# 6                           Fribourg                 1700  Switzerland
# 7                              Reims                51100       France
# 8                               Bern                 3012  Switzerland
# 9                           Salzburg                 5020      Austria
# 10                         Minato-ku     Tokyo   106-0032        Japan
# 11                         Stuttgart                70563      Germany
# 12                            Munich                80686      Germany
# 13                      Glen Waverly  Victoria       3150    Australia
# 14                  Saint Petersburg               196143       Russia
#
#    salesRepEmployeeNumber creditLimit
# 0                    1611   117300.00
# 1                    1504    69400.00
# 2                    1501    92700.00
# 3                    1621    58600.00
# 4                    1401   120800.00
# 5                    1323    89600.00
# 6                                0.00
# 7                    1337    81100.00
# 8                    1702        0.00
# 9                    1401    71700.00
# 10                   1621    94400.00
# 11                               0.00
# 12                   1504    77000.00
# 13                   1611    60300.00
# 14                               0.00

# %% [markdown]
# ## Reflection Question:
#
# Describe the WHERE clause you used in the above query to a non-technical manager who wants to be ensured that you are properly filtering and only selecting the requested data. How is the operator and conditional expression you are using acting to accomplish this?
#
# The WHERE clause is a two-part filter on our customer list. The first condition is country <> 'USA'. <> means not equals, so this condition filters out domestic customers. The second condition is customerName LIKE '%Collect%'. LIKE is used for text matching. The string 'Collect' is in the middle, and the % before and after mean that any character can appear before or after 'Collect', so this condition searches for any customer whose business name contains the word 'Collect'. Using AND means that both conditions must be true for a customer to not be filtered out by the WHERE clause.

# %% [markdown]
# ### Step 4: USA Credit and Inventory Policy - Visual Required
# The USA based product team is planning to adjust its credit policies and inventory allocation strategy based on the average credit limit of its customers. They would like to target this strategy at a state level with several goals in mind.
# 1. Optimize inventory distribution:
#     - States with higher average credit limits might be able to place larger orders, justifying priority in inventory allocation.
#     - This could help ensure that states with more purchasing power always have products in stock.
# 2. Tailor credit policies:
#     - Adjust credit limits for new customers based on the state average.
#     - Identify states where they might be too conservative or too liberal with credit limits.
# 3. Target marketing and sales efforts:
#     - Focus promotional campaigns on states with higher credit limits, potentially leading to larger orders.
#     - Develop strategies to increase sales in states with lower average credit limits.
#
# Execute a SQl query that returns the information required to address this ask.

# %%
# Replace None with your code
step4 = pd.read_sql("""
    SELECT state, AVG(CAST(creditLimit AS REAL)) AS avg_credit_limit
    FROM customers
    WHERE country = 'USA'
    GROUP BY state
""", conn)

step4
# Out:
#   state  avg_credit_limit
# 0    CA      83854.545455
# 1    CT      57350.000000
# 2    MA      70755.555556
# 3    NH     114200.000000
# 4    NJ      43000.000000
# 5    NV      71800.000000
# 6    NY      89966.666667
# 7    PA      84766.666667

# %% [markdown]
# Once you have the information returned in a dataframe, select an appropriate visualization to represent this data. You are welcome to utilize matplotlib, seaborn, or pandas plotting to produce your visual. Ensure that it has a verbose title and axis labels!

# %%
# Replace None with your visual code
# Produce a visual to represent the average credit limit by state

# fig, ax = plt.subplots(figsize=(10, 6))
# ax.bar(step4['state'], step4.sort_values('avg_credit_limit', ascending=False)['avg_credit_limit'])
# ax.set_title('Average Customer Credit Limit by US State')
# ax.set_xlabel('State')
# ax.set_ylabel('Average Credit Limit (USD)')

step4_sorted = step4.sort_values('avg_credit_limit', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(data=step4_sorted, x='state', y='avg_credit_limit')
plt.title('Average Customer Credit Limit by US State')
plt.xlabel('State')
plt.ylabel('Average Credit Limit (USD)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 5: Top Customers - Visual Required
# The company is approaching its 10 year anniversary and wants to acknowledge and thank its top customers with personalized communication. They have asked you to determine the top 10 customers based on the total amount of payments made, making sure to return the customer name for clarity.
#
# Execute a SQl query that returns the information required to address this ask.

# %%
# Replace None with your code
step5 = pd.read_sql("""
    SELECT c.customerName, SUM(p.amount) as total_payments
    FROM customers c
    JOIN payments p ON c.customerNumber = p.customerNumber
    GROUP BY c.customerName
    ORDER BY total_payments DESC
    LIMIT 10
 """, conn)

step5
# Out:
#                    customerName  total_payments
# 0        Euro+ Shopping Channel       715738.98
# 1  Mini Gifts Distributors Ltd.       584188.24
# 2    Australian Collectors, Co.       180585.07
# 3            Muscle Machine Inc       177913.95
# 4       Dragon Souveniers, Ltd.       156251.03
# 5    Down Under Souveniers, Inc       154622.08
# 6                AV Stores, Co.       148410.09
# 7       Anna's Decorations, Ltd       137034.22
# 8      Corporate Gift Ideas Co.       132340.78
# 9        Saveley & Henriot, Co.       130305.35

# %% [markdown]
# Once you have the information returned in a dataframe, select an appropriate visualization to represent this data. You are welcome to utilize matplotlib, seaborn, or pandas plotting to produce your visual. Ensure that it has a verbose title and axis labels!

# %%
# Replace None with your visual code
# Produce a visual to represent the top ten customers in terms of total payments
plt.figure(figsize=(10, 6))
sns.barplot(data=step5, x='customerName', y='total_payments')
plt.title('Top 10 Customers Based on Total Amount of Payments Made')
plt.xlabel('Name')
plt.ylabel('Total Amount of Payments Made')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 6: Top Customer + Product Quantities
# The product team is running an analysis on popular and common products sold to each customer in order to try and determine what new products they should be looking at to include in their catalog. This data will also be used by individual sales reps to recommend similar products to each customer next time they place an order.
#
# They have asked you to query information, for each customer, about any product they have purchased 10 or more units of. In addition they would like the full set of data to be sorted in ascending order by the total amount purchased.
#
# Execute a SQl query that returns the information required to address this ask.
#
# Hint: For this one, you'll need to make use of HAVING, GROUP BY, and ORDER BY — make sure you get the order of them correct!

# %%
# Replace None with you code
step6 = pd.read_sql("""
    SELECT c.customerName, od.productCode, SUM(od.quantityOrdered) AS total_quantity
        FROM customers c
        JOIN orders o ON c.customerNumber = o.customerNumber
        JOIN orderdetails od ON o.orderNumber = od.orderNumber
        GROUP BY c.customerName, od.productCode
        HAVING total_quantity >= 10
        ORDER BY total_quantity ASC
 """, conn)

step6
# Out:
#                        customerName productCode  total_quantity
# 0     Extreme Desk Decorations, Ltd    S24_4620              10
# 1                        Petit Auto    S18_2949              10
# 2                 La Rochelle Gifts    S32_2509              11
# 3           Tekni Collectables Inc.   S700_1691              11
# 4         The Sharp Gifts Warehouse    S24_3191              13
# ...                             ...         ...             ...
# 2526         Euro+ Shopping Channel    S24_3432             174
# 2527         Euro+ Shopping Channel    S12_4473             183
# 2528         Euro+ Shopping Channel    S24_1444             197
# 2529         Euro+ Shopping Channel    S24_2840             245
# 2530         Euro+ Shopping Channel    S18_3232             308
#
# [2531 rows x 3 columns]

# %% [markdown]
# ### Step 7: Product Analysis - Visual Required
#
# The product team is looking into the demand across its different product lines. They are conducting a comprehensive review of its product portfolio and inventory management strategies. You have been asked to query data pertaining to each different product line, that contains the total quantity ordered and the total number of products for each respective product line. By examining the number of products and total quantity ordered for each product line, the company aims to:
# 1. Optimize product mix:
#     - Identify which product lines have the most diverse offerings (high number of products)
#     - Determine which lines are most popular (high total quantity ordered)
#     - Compare if lines with more products necessarily lead to more orders
# 2. Improve inventory management:
#     - Adjust stock levels based on the popularity of each product line
#     - Identify potential overstocking in lines with low order quantities
#     - Ensure adequate variety in high-performing product lines
# 3. Adjust marketing strategy:
#     - Focus promotional efforts on product lines with high potential (many products but lower order quantities)
#     - Capitalize on the popularity of high-performing lines in marketing campaigns
# 4. Advise Product development:
#     - Invest in expanding product ranges for lines with high order quantities
#     - Consider phasing out or revamping product lines with low numbers of products and low order quantities
#
# Hint: Think about how you can and might have to utilize SQL DISTINCT statement
#
# Execute a SQl query that returns the information required to address this ask.

# %%
# Replace None with your code
step7 = pd.read_sql("""
    SELECT pl.productLine, SUM(od.quantityOrdered) AS total_quantity, COUNT(DISTINCT p.productCode) AS num_products
    FROM productlines pl
    JOIN products p ON pl.productLine = p.productLine
    JOIN orderdetails od ON p.productCode = od.productCode
    GROUP BY pl.productLine
 """, conn)

step7
# Out:
#         productLine  total_quantity  num_products
# 0      Classic Cars           35582            37
# 1       Motorcycles           12778            13
# 2            Planes           11872            12
# 3             Ships            8532             9
# 4            Trains            2818             3
# 5  Trucks and Buses           11001            11
# 6      Vintage Cars           22933            24

# %% [markdown]
# Once you have the information returned in a dataframe, select an appropriate visualization to represent the relationship between total quantity ordered and the number of products in order to perform a preliminary investigation into the question of if more products lead to more orders. You are welcome to utilize matplotlib, seaborn, or pandas plotting to produce your visual. Ensure that it has a verbose title and axis labels!

# %%
# Replace None with your visual code
# Produce a visual to represent the the relation between number of products and the total amount ordered
plt.figure(figsize=(10, 6))
sns.scatterplot(data=step7, x='num_products', y='total_quantity', hue='productLine')
sns.regplot(data=step7, x='num_products', y='total_quantity', scatter=False, color='gray', line_kws={'linestyle': '--'})
plt.title('Relationship Between Number of Products and Total Quantity Ordered by Product Line')
plt.xlabel('Number of Products')
plt.ylabel('Total Quantity Ordered')
plt.legend(title='Product Line') 
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Reflection Question:
#
# Please explain your choice in the type of visual you used in order to highlight and represent the data from the above query. In a non-technical manner explain why that chart type makes sense for the information being conveyed. What does this visual convey in the context of the question it was asked for?
#
# For this visualization, I chose a scatter plot with a best fit line. The scatter plot shows the relationship between the two values. Each dot represents a product line, positioned by its number of products (horizontal axis) and its total quantity ordered (vertical axis). Since the dots trend upwards from left to right, it suggests that having more products leads to more orders. I added the best line fit to emphasize the trend, though it is visible from the scatterplot alone. This visual gives the product team a clear answer: expanding a product line's catalog does drive more sales volume.

# %% [markdown]
# ### Step 8: Remote Offices
# Upper management is considering a shift to hybrid and remote work for certain locations and roles. They have tasked you with providing them data about employees who work in any office that has fewer than 5 total employees so they can better understand how to support those employees remotely when offices are shut down.
#
# Be sure to include information about the employees job and supervisor so management can adjust everyone to remote work properly.
#
# Hint: Utilize a subquery to find the relevant offices
#
# Execute a SQl query that returns the information required to address this ask.

# %%
# Replace None with your code
step8 = pd.read_sql("""
    SELECT e.firstName, e.lastName, e.jobTitle, e.reportsTo,
           m.firstName AS supervisorFirstName, m.lastName AS supervisorLastName
    FROM employees e
    JOIN employees m ON e.reportsTo = m.employeeNumber
    WHERE e.officeCode IN (
        SELECT officeCode
        FROM employees
        GROUP BY officeCode
        HAVING COUNT(*) < 5
    )
""", conn)

step8
# Out:
#    firstName   lastName              jobTitle reportsTo supervisorFirstName  \
# 0    William  Patterson  Sales Manager (APAC)      1056                Mary
# 1      Julie   Firrelli             Sales Rep      1143             Anthony
# 2      Steve  Patterson             Sales Rep      1143             Anthony
# 3   Foon Yue      Tseng             Sales Rep      1143             Anthony
# 4     George     Vanauf             Sales Rep      1143             Anthony
# 5      Larry       Bott             Sales Rep      1102              Gerard
# 6      Barry      Jones             Sales Rep      1102              Gerard
# 7       Andy     Fixter             Sales Rep      1088             William
# 8      Peter      Marsh             Sales Rep      1088             William
# 9        Tom       King             Sales Rep      1088             William
# 10      Mami      Nishi             Sales Rep      1056                Mary
# 11   Yoshimi       Kato             Sales Rep      1621                Mami
#
#    supervisorLastName
# 0           Patterson
# 1                 Bow
# 2                 Bow
# 3                 Bow
# 4                 Bow
# 5              Bondur
# 6              Bondur
# 7           Patterson
# 8           Patterson
# 9           Patterson
# 10          Patterson
# 11              Nishi

# %% [markdown]
# ## Reflection Question:
#
# Describe how you decided on the subquery that you used in the query above? This answer can be technically in nature, describing your thought process in how the main query is utilizing the subquery to return the correct data.
#
# For the subquery, I needed to filter to offices with less than 5 employees. To get the number of employees in each office, I SELECT officeCode from employees. Then, I group them by officeCode. This is necessary so that the aggregation COUNT counts the number of entries in the group, with the group being the office. This allows HAVING COUNT(*) < 5 to count the number of employees in the office.

# %% [markdown]
# ### Step 9: Close the Connection
#
# Now that you are finished executing your queries and retrieving the required information you always want to make sure to close the connection to your database.

# %%
# Replace None with your code
conn.close()

# %% [markdown]
# ### End of Guided Section
# In this initial portion of the assessment, you produced several data queries and visualizations for a model company, mainly focused around its customer and product data. You wrote and engineered specific SQL queries to address pertinent questions and asks from the company. Along the way, you utilized many of the major concepts and keywords associated with SQL SELECT queries: FROM, WHERE, GROUP BY, HAVING, ORDER BY, JOIN, SUM, COUNT, and AVG.
#
# ## Part 2: Exploratory Analysis with SQL
# In this open-ended exploratory section, you will analyze real-world data from the movie industry. As a data analyst, you have the freedom to investigate questions and topics that intrigue you within this dataset. The database schema and Entity-Relationship Diagram (ERD) are provided below for your reference. A general overview and instructions are also provided below.

# %%
# Run this cell without changes
import zipfile

zip_file_path = 'im.db.zip'
extract_to_path = './'

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to_path)

# Connection
conn4 = sqlite3.connect('im.db')

# Schema
schema_df = pd.read_sql("""
SElECT * FROM sqlite_master                        
""", conn4)
schema_df
# Out:
#     type           name       tbl_name  rootpage  \
# 0  table   movie_basics   movie_basics         2
# 1  table      directors      directors         3
# 2  table      known_for      known_for         4
# 3  table     movie_akas     movie_akas         5
# 4  table  movie_ratings  movie_ratings         6
# 5  table        persons        persons         7
# 6  table     principals     principals         8
# 7  table        writers        writers         9
#
#                                                  sql
# 0  CREATE TABLE "movie_basics" (\n"movie_id" TEXT...
# 1  CREATE TABLE "directors" (\n"movie_id" TEXT,\n...
# 2  CREATE TABLE "known_for" (\n"person_id" TEXT,\...
# 3  CREATE TABLE "movie_akas" (\n"movie_id" TEXT,\...
# 4  CREATE TABLE "movie_ratings" (\n"movie_id" TEX...
# 5  CREATE TABLE "persons" (\n"person_id" TEXT,\n ...
# 6  CREATE TABLE "principals" (\n"movie_id" TEXT,\...
# 7  CREATE TABLE "writers" (\n"movie_id" TEXT,\n  ...

# %% [markdown]
# ## The Data
#
# ![movie ERD](images/movie_data_erd.jpeg)
# ### Database Content:
#
# - Source: IMDB
# - Time Range: Movies released between 2010 and 2019
# - Note: Exclude any movies with a start_year after 2019 as this data is not current or accurate
#
# Available Data Categories:
# - Genre
# - Runtime
# - Personnel (writers, directors, actors)
# - Movie ratings
#
# ### Objectives:
#
# Initial Exploration:
# - Use SQL in combination with Pandas to explore the database
# - Identify interesting trends, patterns, or relationships in the data
#
# Business Question Formulation:
# - Develop at least one substantial business question for deeper analysis
# - Ensure the question is relevant, specific, and can be addressed with the available data
#
# Data Cleaning Assessment:
# - Identify potential data cleaning tasks necessary for your deeper analysis
# - Note: You are not required to perform the cleaning, only to recognize and list the necessary tasks
#
# Null Value Handling:
# - Be aware that the dataset contains null values in certain fields
# - Exclude these null values from your exploration
# - Do not attempt to input or fill in missing information
#
# ### Deliverables:
#
# You need to produce a short slide presentation (3-5 slides) that highlights the three key deliverables below. Utilize a data visualization to support the second deliverable.
#
# 1. A summary of your initial data exploration findings
#     - Can be bulleted or sentence form
# 2. At least one well-formulated business question for further analysis
#     - Should stem from a relevant trend or pattern your initial exploration identified
# 3. A list of potential data cleaning tasks identified during your exploration
#     - This can and should include things like data normalization/standardization and null handling
#
# Tips for Success:
#
# Begin with broad exploratory queries to understand the data's scope and content. Then focus on honing in on interesting relationships between different data categories. Consider industry trends, audience preferences, or financial aspects when formulating your business question. Pay attention to data quality issues, inconsistencies, or limitations that might affect your analysis. Remember, the goal is to demonstrate your analytical thinking and ability to derive meaningful insights from complex datasets. Good luck with your exploration!
#
# NOTE: You do not need to explore every aspect of this database. Find something that you think is interesting or relevant about the data and focus your exploration there.

# %%
# Begin your code here
movies = pd.read_sql("""
    SELECT *
    FROM movie_basics mb
    JOIN movie_ratings mr ON mb.movie_id = mr.movie_id
    JOIN movie_akas ma ON mr.movie_id = ma.movie_id
""", conn4)

# weighted_rating is computed using the Bayesian weighted rating.
# This is so that the movie's rating is balanced to how many votes it has.
# Before I added this, averagerating was unbalanced (e.g. there are 10* movies with only 5 votes).
# This is an inaccurate way to rank the movies, so I researched weighted rating systems. 
weighted_rated = pd.read_sql("""
    SELECT *,
        (CAST(mr.numvotes AS REAL) / (CAST(mr.numvotes AS REAL) + 1000)) * mr.averagerating
        + (1000.0 / (CAST(mr.numvotes AS REAL) + 1000)) * (SELECT AVG(averagerating) FROM movie_ratings)
        AS weighted_rating
    FROM movie_basics mb
    JOIN movie_ratings mr ON mb.movie_id = mr.movie_id
    ORDER BY weighted_rating DESC
""", conn4)

movies_by_runtime = pd.read_sql("""
    SELECT *,
        (CAST(mr.numvotes AS REAL) / (CAST(mr.numvotes AS REAL) + 1000)) * mr.averagerating
        + (1000.0 / (CAST(mr.numvotes AS REAL) + 1000)) * (SELECT AVG(averagerating) FROM movie_ratings)
        AS weighted_rating
    FROM movie_basics mb
    JOIN movie_ratings mr ON mb.movie_id = mr.movie_id
    WHERE mb.runtime_minutes IS NOT NULL
    ORDER BY mb.runtime_minutes ASC
 """, conn4)

# There are some major outliers from movies_by_runtime, so I reevaluated.
# I made the decision to exclude documentaries and movies longer than 240 minutes,
# so I could focus the analysis on "traditional" moves.
traditional_movies_by_runtime = pd.read_sql("""
    SELECT *,
        (CAST(mr.numvotes AS REAL) / (CAST(mr.numvotes AS REAL) + 1000)) * mr.averagerating
        + (1000.0 / (CAST(mr.numvotes AS REAL) + 1000)) * (SELECT AVG(averagerating) FROM movie_ratings)
        AS weighted_rating
    FROM movie_basics mb
    JOIN movie_ratings mr ON mb.movie_id = mr.movie_id
    WHERE mb.runtime_minutes IS NOT NULL AND mb.genres NOT LIKE '%Documentary%' AND mb.runtime_minutes <= 240
    ORDER BY mb.runtime_minutes ASC
 """, conn4)

# Another approach is to categorize them into 'short', 'medium', 'long' for categorical analysis.
movies_by_duration = pd.read_sql("""
    SELECT *,
        CASE
            WHEN mb.runtime_minutes < 60 THEN 'short'
            WHEN mb.runtime_minutes BETWEEN 60 AND 90 THEN 'medium'
            WHEN mb.runtime_minutes > 90 then 'long'
        END AS duration,
        (CAST(mr.numvotes AS REAL) / (CAST(mr.numvotes AS REAL) + 1000)) * mr.averagerating
        + (1000.0 / (CAST(mr.numvotes AS REAL) + 1000)) * (SELECT AVG(averagerating) FROM movie_ratings)
        AS weighted_rating
    FROM movie_basics mb
    JOIN movie_ratings mr ON mb.movie_id = mr.movie_id
    WHERE mb.runtime_minutes IS NOT NULL
    ORDER BY mb.runtime_minutes ASC
 """, conn4)

movies
# Out:
#          movie_id              primary_title             original_title  \
# 0       tt0063540                  Sunghursh                  Sunghursh
# 1       tt0063540                  Sunghursh                  Sunghursh
# 2       tt0063540                  Sunghursh                  Sunghursh
# 3       tt0063540                  Sunghursh                  Sunghursh
# 4       tt0063540                  Sunghursh                  Sunghursh
# ...           ...                        ...                        ...
# 261801  tt9905462                  Pengalila                  Pengalila
# 261802  tt9905462                  Pengalila                  Pengalila
# 261803  tt9911774  Padmavyuhathile Abhimanyu  Padmavyuhathile Abhimanyu
# 261804  tt9911774  Padmavyuhathile Abhimanyu  Padmavyuhathile Abhimanyu
# 261805  tt9911774  Padmavyuhathile Abhimanyu  Padmavyuhathile Abhimanyu
#
#         start_year  runtime_minutes              genres   movie_id  \
# 0             2013            175.0  Action,Crime,Drama  tt0063540
# 1             2013            175.0  Action,Crime,Drama  tt0063540
# 2             2013            175.0  Action,Crime,Drama  tt0063540
# 3             2013            175.0  Action,Crime,Drama  tt0063540
# 4             2013            175.0  Action,Crime,Drama  tt0063540
# ...            ...              ...                 ...        ...
# 261801        2019            111.0               Drama  tt9905462
# 261802        2019            111.0               Drama  tt9905462
# 261803        2019            130.0               Drama  tt9911774
# 261804        2019            130.0               Drama  tt9911774
# 261805        2019            130.0               Drama  tt9911774
#
#         averagerating  numvotes   movie_id  ordering  \
# 0                 7.0        77  tt0063540         1
# 1                 7.0        77  tt0063540         2
# 2                 7.0        77  tt0063540         3
# 3                 7.0        77  tt0063540         4
# 4                 7.0        77  tt0063540         5
# ...               ...       ...        ...       ...
# 261801            8.4       600  tt9905462         2
# 261802            8.4       600  tt9905462         3
# 261803            8.4       365  tt9911774         1
# 261804            8.4       365  tt9911774         2
# 261805            8.4       365  tt9911774         3
#
#                              title region language     types  \
# 0                        Sangharsh     IN       hi      None
# 1                        Sunghursh   None     None  original
# 2                        Sunghursh     IN     None      None
# 3                        Sunghursh     IN       hi      None
# 4                        Sungharsh     IN       hi      None
# ...                            ...    ...      ...       ...
# 261801                  Sisterleaf     IN       en      None
# 261802                   Pengalila     IN     None      None
# 261803   Padmavyuhathile Abhimanyu   None     None  original
# 261804  Pathmavyuhathile Abhimanyu     IN       ml      None
# 261805  Padmavyoohathile Abhimanyu     IN       ml      None
#
#                          attributes  is_original_title
# 0       alternative transliteration                0.0
# 1                              None                1.0
# 2                              None                0.0
# 3       alternative transliteration                0.0
# 4              alternative spelling                0.0
# ...                             ...                ...
# 261801        literal English title                0.0
# 261802                         None                0.0
# 261803                         None                1.0
# 261804         alternative spelling                0.0
# 261805         alternative spelling                0.0
#
# [261806 rows x 17 columns]

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=traditional_movies_by_runtime, x='runtime_minutes', y='weighted_rating', alpha=0.1)
sns.regplot(data=traditional_movies_by_runtime, x='runtime_minutes', y='weighted_rating', scatter=False, color='red', line_kws={'linestyle': '--'})
plt.title('Movie Runtime vs Weighted Rating')
plt.xlabel('Runtime (Minutes)')
plt.ylabel('Weighted Rating')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=movies_by_duration, x='duration', y='weighted_rating', order=['short', 'medium', 'long'])
plt.title('Weighted Rating Distribution by Movie Duration')
plt.xlabel('Duration')
plt.ylabel('Weighted Rating')
plt.tight_layout()
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

sns.scatterplot(data=traditional_movies_by_runtime, x='runtime_minutes', y='numvotes', alpha=0.2, s=20, ax=ax1, color='blue')
ax1.set_yscale('log')
ax1.set_xlabel('Runtime (Minutes)')
ax1.set_ylabel('Number of Ratings (log scale)')
ax1.tick_params(axis='y')

plt.title('Movie Runtime vs Number of Ratings')
plt.tight_layout()
plt.show()
